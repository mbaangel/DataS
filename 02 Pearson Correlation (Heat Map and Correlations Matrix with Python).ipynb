# %%
import matplotlib.pyplot as plt
import pandas as pd

personas = pd.read_csv("datos/personas.csv")
personas

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Weight and Height Relation

# %%
plt.scatter(personas["height"], personas("weight"))
plt.xlabel("Height (cms)")
plt.ylabel("Weight (kgs)")
plt.show()

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Relation: Work hours and Incomes

# %%
plt.scatter(personas["Income"], personas["work_hours"])
plt.xlabel("Incomes ($)")
plt.ylabel("Worked hours")
plt.show

# %% [markdown]
# Relation: Absences and Admission

# %%
plt.scatter(personas["Income", personas["Ausencias"]])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-1c2f558e17fc> in <cell line: 1>()
# ----> 1 plt.scatter(personas["Income", personas["Ausencias"]])
#
# NameError: name 'personas' is not defined

# %%
plt.scatter(personas["Income"], personas["Ausencias"])
plt.xlabel("Income ($)")
plt.ylabel("Ausencias")
plt.show()

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Correlation Matrix

# %%
matrix = personas.corr() # -1 (strong relation) 0 1 (Exist an strong relation)
plt.matshow(matriz, cmap="bwr", vmin=-1, vmax=1)
plt.xticks(range(5), personas.columns, rotation=90)
plt.yticks(range(5), personas.columns)

for i in range(len(matrix.columns)):
    for j in range(len(matrix.columns)):
