# %%
import pandas as pd
index = ["John", "Mary", "Joseph", "Peter", "Lois"]
data_list = [40, 20, 36, 34, 20]

# %%
ages = pd.Series(data_list, index)
ages
# Out:
# John      40
# Mary      20
# Joseph    36
# Peter     34
# Lois      20
# dtype: int64

# %%
data = {"John":40, "Mary":20, "Joseph": 36, "Peter":34, "Lois":20}
ages = pd.Series(data)
ages
# Out:
# John      40
# Mary      20
# Joseph    36
# Peter     34
# Lois      20
# dtype: int64

# %% [markdown]
# # Attibutes and Data Series

# %%
ages.dtype, ages.size, ages.index, ages.values
# Out:
# (dtype('int64'),
#  5,
#  Index(['John', 'Mary', 'Joseph', 'Peter', 'Lois'], dtype='object'),
#  array([40, 20, 36, 34, 20]))

# %%
for element in ages.index:
  print(element)
# Out:
# John
# Mary
# Joseph
# Peter
# Lois

# %%
ages["John"]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-4b615f8646e6> in <cell line: 1>()
# ----> 1 ages["John"]
#
# TypeError: string indices must be integers

# %%
ages[0], ages[0:2], ages[0:3]
# Out:
# ('J', 'Jo', 'Joh')

# %% [markdown]
# # Common basic methods

# %%
import pandas as pd
ages.astype("float")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-28-11cbc4e4ce46> in <cell line: 2>()
#       1 import pandas as pd
# ----> 2 ages.astype("float")
#
# AttributeError: 'str' object has no attribute 'astype'

# %%
ages.value_counts()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-30-f431a276f5d4> in <cell line: 1>()
# ----> 1 ages.value_counts()
#
# AttributeError: 'str' object has no attribute 'value_counts'

# %%
ages + 1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-31-e2af19a02f88> in <cell line: 1>()
# ----> 1 ages + 1
#
# TypeError: can only concatenate str (not "int") to str

# %%
ages.describe()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-32-71369addeaa3> in <cell line: 1>()
# ----> 1 ages.describe()
#
# AttributeError: 'str' object has no attribute 'describe'

# %%
ages.plot()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-33-b26014a24201> in <cell line: 1>()
# ----> 1 ages.plot()
#
# AttributeError: 'str' object has no attribute 'plot'
